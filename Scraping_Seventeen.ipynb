# %% [markdown]
# <a href="https://colab.research.google.com/github/KueKarambiaaa/Proyek-Analisis-Sentimen/blob/main/Scraping_Seventeen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Scraping 🧳The Game Caterers 2 X SEVENTEEN from Youtube

# %%
# !pip install --upgrade google-api-python-client
# !pip install langdetect
# !pip install pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BaseDir = '/content/drive/MyDrive/Colab Notebooks/Scraping Seventeen.ipynb'

# %%
from googleapiclient.discovery import build
from langdetect import detect
import pandas as pd

# API key
api_key = 'AIzaSyCGKbDOcYUJTo96KHNeOZk1OtzGida79JE'
youtube = build('youtube', 'v3', developerKey=api_key)

def get_video_comments(video_id, max_results=100):
    comments = []
    next_page_token = None

    while len(comments) < max_results:
        response = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            textFormat="plainText",
            maxResults=min(100, max_results - len(comments)),
            pageToken=next_page_token
        ).execute()

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            published_at = item['snippet']['topLevelComment']['snippet']['publishedAt']
            try:
                language = detect(comment)
            except:
                language = "unknown"
            comments.append({"comment": comment, "publishedAt": published_at, "language": language})

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

    return comments[:max_results]

# ID video
video_id = 'UF0JiR3oTH8'

comments = get_video_comments(video_id, max_results=10000)

for idx, comment_data in enumerate(comments, 1):
    print(f"{idx}. {comment_data['comment']} (Published at: {comment_data['publishedAt']}, Language: {comment_data['language']})")
# Out:
# Streaming output truncated to the last 5000 lines.
# 5808. i'm soo happy for themm!!😊💖 (Published at: 2023-05-20T11:23:46Z, Language: en)
# 5809. JOSWAAAAA 🤣🤣🤣🤣🤣🤣🤣🤣 (Published at: 2023-05-20T11:23:09Z, Language: pt)
# 5810. I laughed so loudly in this episode.. (Published at: 2023-05-20T11:22:55Z, Language: en)
# 5811. DK is slayed the pink venom!!!!!! (Published at: 2023-05-20T11:22:31Z, Language: en)
# 5812. looking forward to the youth over flowers with seventeen!! it's gonna cost a lot, i lowkey feel bad for the production team lol plus it's gonna be so hard fooling these 13 men. good luck na-pd and production team 😆🤍 (Published at: 2023-05-20T11:22:05Z, Language: en)
# 5813. Such a wonderfull épisode i love it seventeen Love you and i was laughting so hard 😂😂😂❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤ (Published at: 2023-05-20T11:21:59Z, Language: en)
# 5814. 혹시 마지막 엔딩곡 제목이 뭔가여,,,,?! (Published at: 2023-05-20T11:21:25Z, Language: ko)
# ...

# %%
data = {
    "Komentar": ["I love U Seventeen", "Dammmnnn", "Group yang sangat lucu!"],
    "Sentimen": ["Positif", "Negatif", "Positif"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                   Komentar Sentimen
# 0       I love U Seventeen  Positif
# 1                 Dammmnnn  Negatif
# 2  Group yang sangat lucu!  Positif

# %%
scrapreview = get_video_comments(video_id)
df = pd.DataFrame(scrapreview)
print(df)
# Out:
#                                               comment           publishedAt  \
# 0   im here again watching it again, please make a...  2025-01-17T15:25:04Z
# 1   23:57 "your panda became the youngest member o...  2025-01-16T20:37:06Z
# 2                   가끔보면 조슈아 몸속에 1호선 할배의 영혼이 들어있는거같음ㅋ  2025-01-16T10:00:39Z
# 3   i've been having multiple mental breakdowns bu...  2025-01-16T06:51:33Z
# 4                  at 1:20 minghao said it so cutelyy  2025-01-15T23:18:14Z
# ..                                                ...                   ...
# 95            shua is so fuckin weird lmao i love him  2024-12-03T21:22:41Z
# 96                         selalu suka sama eps ini😂❤  2024-12-03T17:05:17Z
# 97                        조슈아~~어쩐댜 너무 웃겨~춤 어쩔 배꼽 빠지것네  2024-12-03T11:56:28Z
# 98  Thank you, wonwoo because we had nana tour. Na...  2024-12-03T00:40:38Z
# 99  The comment ....hybe artist are just mixing sm...  2024-12-02T20:29:21Z
#
#    language
# 0        en
# 1        en
# 2        ko
# ...

# %%
df.to_csv('The Game Caterers 2 X SEVENTEEN.csv', index=False, encoding='utf-8')
